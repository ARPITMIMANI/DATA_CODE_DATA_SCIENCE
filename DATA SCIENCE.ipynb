# %%
''' 
DATA SCIENCE : IT IS ABOUT DATA GATHERING , DATA ANALYSIS AND DECISION MAKING . 
IT IS ABOUT FINDING PATTERNS IN DATA , THROUGH ANALYSIS AND MAKE FUTURE PREDICTIONS .

BY USING DATA SCIENCE COMPANIES ARE ABLE TO MAKE:
1. BETTER DECISIONS ( SHOULD WE CHOOSE A OR B )
2. PREDICTIVE ANALYSIS ( WHAT WILL HAPPEN NEXT )
3. PATTERN DISCOVERIES ( FIND PATTERN OR MAY BE HIDDEN INFORMATION IN THE DATA )

DATA SCIENCE IS USED IN MANY INDUSTRIES IN THE WORLD TODAY .
EXAMPLE : BANKING , CONSULTANCY , HEALTHCARE AND MANUFACTURING .

EXAMPLES OF WHERE DATA SCIENCE IS NEEDED :
1. FOR ROUTE PLANNING TO DISCOVER THE BEST ROUTES TO SHIPS .
2. TO FORSEE DELAYS FOR FLIGHT / SHIP / TRAIN ETC... THROUGH PREDECTIVE ANALYSIS .
3. TO CREATE PROMOTIONAL OFFERS .
4. TO FIND THE BEST SUITED TIME TO DELIVER GOODS .
5. TO FORECAST THE NEXT YEARS REVENUE FOR A COMPANY .
6. TO ANALYZE HEALTH BENEFIT OF TRAINING .
7. TO PREDICT WHO WILL WIN ELECTIONS .

DATA SCIENCE CAN BE APPLIED IN NEARLY EVERY PART OF A BUSINESS WHERE DATA IS AVAILABLE .
EXAMPLES ARE CONSUMER GOODS , STOCK MARKET , INDUSTRY , POLITICS , LOGISTIC COMPANIES , E-COMMERCE .

A DATA SCIENCE REQUIRES EXPERTISE IN SEVERAL BACKGROUNDS :
1. MACHINE LEARING .
2. STATISTICS .
3. PYTHON PROGRAMMING .
4. MATHEMATICS .
5. DATABASES .
'''
# Out:
# ' \nDATA SCIENCE : IT IS ABOUT DATA GATHERING , DATA ANALYSIS AND DECISION MAKING . \nIT IS ABOUT FINDING PATTERNS IN DATA , THROUGH ANALYSIS AND MAKE FUTURE PREDICTIONS .\n\nBY USING DATA SCIENCE COMPANIES ARE ABLE TO MAKE:\n1. BETTER DECISIONS ( SHOULD WE CHOOSE A OR B )\n2. PREDICTIVE ANALYSIS ( WHAT WILL HAPPEN NEXT )\n3. PATTERN DISCOVERIES ( FIND PATTERN OR MAY BE HIDDEN INFORMATION IN THE DATA )\n\nDATA SCIENCE IS USED IN MANY INDUSTRIES IN THE WORLD TODAY .\nEXAMPLE : BANKING , CONSULTANCY , HEALTHCARE AND MANUFACTURING .\n\nEXAMPLES OF WHERE DATA SCIENCE IS NEEDED :\n1. FOR ROUTE PLANNING TO DISCOVER THE BEST ROUTES TO SHIPS .\n2. TO FORSEE DELAYS FOR FLIGHT / SHIP / TRAIN ETC... THROUGH PREDECTIVE ANALYSIS .\n3. TO CREATE PROMOTIONAL OFFERS .\n4. TO FIND THE BEST SUITED TIME TO DELIVER GOODS .\n5. TO FORECAST THE NEXT YEARS REVENUE FOR A COMPANY .\n6. TO ANALYZE HEALTH BENEFIT OF TRAINING .\n7. TO PREDICT WHO WILL WIN ELECTIONS .\n\nDATA SCIENCE CAN BE APPLIED IN NEARLY EVE
# ...
