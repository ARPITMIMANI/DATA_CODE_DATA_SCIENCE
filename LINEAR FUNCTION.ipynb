# %%
'''
LINEAR FUNCTION : IT HAS ONE INDEPENDENT VARIABLE AND ONE DEPENDENT VARIABLE 
AND HAS THE FORM y = f(x) = ax + b WHERE ,

y = OUTPUT THAT IS DEPENDENT VATIABLE .

x = INPUT THAT IS INDEPENDENT VATIABLE .

a =  SLOPE THAT IS THE COEFFICIENT OF INDEPENDENT VARIABLE . 
IT GIVES THE RATE OF CHANGE OF INDEPENDENT VARIABLE .

b = INTERCEPT IS THE VALUE OF DEPENDENT VARIABLE .

LINEAR FUNCTION WITH ONE EXPLANATORY VARIABLE : LINEAR FUNCTION USES 
ONLY ONE VARIABLE FOR PREDICTION .

EXAMPLE : f(x) = y = 2x + 80 .
WHERE ,

x = INPUT VALUE WHICH IS "Average_Pulse" .

y = OUTPUT VALUE WHICH IS "Calorie_Burnage" .

2 = SLOPE SPECIFIES HOW MUCH "Calorie_Burnage" INCREASES 
IF THE "Average_Pulse" INCREASE BY ONE UNIT .

80 = INTERCEPT IS THE FIXED VALUE .

'''

# LOAD THE DATA FROM THE CSV FILE "EXERCISE_DATA.csv" INTO THE DATA FRAME .

import pandas as pd 
xyz = pd.read_csv("EXERCISE_DATA.csv")
print ( xyz.to_string() )
# Out:
#    Duration  Average_Pulse  Max_Pulse  Calorie_Burnage  Hours_Work  Hours_Sleep
# 0        30             80        120              240          10            7
# 1        30             85        120              250          10            7
# 2        45             90        130              260           8            7
# 3        45             95        130              270           8            7
# 4        45            100        140              280           0            7
# 5        60            105        140              290           7            8
# 6        60            110        145              300           7            8
# 7        60            115        145              310           8            8
# 8        75            120        150              320           0            8
# 9        75            125        150              330           8            8

# %%
# PLOT THE VALUES OF "Average_Pulse" AGAINST "Calorie_Burnage" BY USING MATPLOTLIB .

import matplotlib.pyplot as plt
import pandas as pd 

xyz = pd.read_csv ( "EXERCISE_DATA.csv" , header=0 , sep="," )
xyz.plot ( x="Average_Pulse" , y="Calorie_Burnage" , kind="line" )

plt.xlim ( xmin=0 )
plt.ylim ( ymin=0 )
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd 

xyz = pd.read_csv ( "EXERCISE_DATA.csv" , header=0 , sep="," )
xyz.plot ( x="Average_Pulse" , y="Calorie_Burnage" , kind="line" )

plt.xlim ( xmin=80 , xmax=150 )
plt.ylim ( ymin=240 , ymax=350 )
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd 

xyz = pd.read_csv ( "EXERCISE_DATA.csv" , header=0 , sep="," )
xyz.plot ( x="Average_Pulse" , y="Calorie_Burnage" , kind="line" )

plt.grid(True)
plt.xlim ( xmin=70 , xmax=150 )
plt.ylim ( ymin=230 , ymax=350 )
plt.show()
